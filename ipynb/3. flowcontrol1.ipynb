# %% [markdown]
# List of keywords
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **FLOW CONTROL STATEMENTS**

# %% [markdown]
# **Boolean Values**
#
#
# 1.   Integer, floating-point, and string data types have an unlimited
# number of possible values
# 2.   Boolean data type has only two values: True and False
# 3.   True and False lack the quotes you place around strings, and start with a capital T or F

# %%
enrolled = False
enrolled

# %%
True = 2+5

# %%
true = 2+4
true
# Out:
# 6

# %% [markdown]
# **Comparison Operators**
#  *Compares two values and evaluaes down to a single boolean value*

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
42==42
# Out:
# True

# %%
34!=25
# Out:
# True

# %%
34<25
# Out:
# False

# %%
'Hello' == "Hello"
# Out:
# True

# %%
True == True

# %%
42==42.0
# Out:
# True

# %%
'42' == 42
# Out:
# False

# %% [markdown]
# **Boolean Operators**
# The three Boolean operators (and, or, and not) are used to compare Boolean values. Like comparison operators, they evaluate these expressions down
# to a Boolean value.

# %% [markdown]
# **Mixing Boolean and Comparison Operators**

# %%
(4>2) and (2>3)
# Out:
# False

# %%
(4>2) or (2>3)
# Out:
# True

# %%
2 + 2 == 4 and not 2 + 2 == 5 and 2 * 2 == 2 + 2
# Out:
# True

# %% [markdown]
# **Order of Precedence**
# Python evaluates the 'not' operators first, then the 'and' operators, and then the 'or' operators.

# %% [markdown]
# **Elements of Flow control**
#
#
# 1.   Condition - Flow control statements often begin with condition
# 2.   Clause - Block of code

# %% [markdown]
# **Flow control statements** - A program’s control flow is the order in which the program’s code executes. The control flow of a Python program is regulated by conditional statements, loops, and function calls.
#
# 1.    Simple if statement
#
# 2.    If ...else statement
#
# 3.    if ...elif...statement

# %% [markdown]
# **Syntax**
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
#Example 1

score_ext = 79
score_int = 18

# %%
if (score_ext + score_int)>100:
  print('Invalid')
else:
  print('valid')
# Out:
# valid

# %%
#Example 2
name = input('Enter your name')
# Out:
# Enter your nameHello

# %%
if name == 'Alice':
  print('Hi, Alice.')
else:
  print('Hello, stranger.')

# %%
age = int(input('Enter your age:'))
# Out:
# Enter your age:50

# %%
if name == 'Alice':
  print('Hi, Alice.')
elif age < 12:
  print('You are not Alice, kiddo.')
elif age > 2000:
  print('Unlike you, Alice is not an undead, immortal vampire.')
elif age > 100:
  print('You are not Alice, grannie.')
else:
  print('not satisfying the above conditions')

# %%
#Example 3
x = int(input("Enter some value"))
if x<0:
  x=0
  print(x)
  print('X is negative and reset to zero')
elif x>99:
   print('x is not a two digit number') 
else:
  print(x)
# Out:
# Enter some value0
# 0

# %%
print('Enter the 3 numbers:')
a=int(input())
b=int(input())
c=int(input())
if(a>b):
  if(a>c):
    print(a)
  else:
    print(c)
else:
  if(b>c):
    print(b)
  else:
    print(c)

# %%
num=int(input('Enter a number'))
if(num%2==0):
  print('Even number')
else:
  print('Odd number')

# %% [markdown]
# Find largest among a, b, c, d

# %%
print('Enter the 4 numbers:')
a=int(input())
b=int(input())
c=int(input())
d=int(input())
if a>b:
  if a>c:
    if a>d:
      print(a)
    else:
      print(d)
  else:
    if c>d:
      print(c)
    else:
      print(d)
else:
  if b>c:
    if b>d:
      print(b)
    else:
      print(d)
  else:
    if c>d:
      print(c)
    else:
      print(d)
# Out:
#   File "<ipython-input-32-b84471f6c299>", line 18
#     if b>c:
#      ^
# IndentationError: expected an indented block
